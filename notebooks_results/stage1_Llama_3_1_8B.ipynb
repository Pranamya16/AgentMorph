# %% [markdown]
# # AgentMorph Stage 1 - **Llama-3.1-8B**
#
# Runs `Llama-3.1-8B` on Colab T4. Each model gets a clean Python process so VRAM fragmentation from prior loads doesn't carry over. All 5 per-model notebooks share one `--out-dir` on Drive; the manifest key includes the model id so there are no file collisions.
#
# **Model size:** mid (~6 GB)
#
# **Default sweep:** `native + langgraph`. smolagents is intentionally excluded — its 30-tool system prompt blows the T4 context budget by step 3-4 (see §8 note).
#
# **Order:** Llama-3.2-3B (canary) -> Qwen2.5-7B -> Llama-3.1-8B -> Gemma-2-9B -> Phi-4 (last; tightest on T4).
#
# **Before you run:** Runtime -> Change runtime type -> **T4 GPU**. Have your HF token ready for §3.

# %% [markdown]
# ## 1. GPU sanity check

# %%
import torch
assert torch.cuda.is_available(), "No CUDA visible. Runtime > Change runtime type > T4 GPU."
dev = torch.cuda.get_device_properties(0)
print(f"CUDA OK: {torch.cuda.get_device_name(0)} ({dev.total_memory / 1024**3:.1f} GB VRAM)")
# Out:
# CUDA OK: Tesla T4 (14.6 GB VRAM)

# %% [markdown]
# ## 2. Clone / pull the repo

# %%
import os
REPO_URL = "https://github.com/Pranamya16/AgentMorph.git"
REPO_DIR = "/content/AgentMorph"
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # !cd {REPO_DIR} && git fetch origin && git checkout main && git pull --ff-only
# !cd {REPO_DIR} && git log -1 --oneline
# Out:
# Cloning into '/content/AgentMorph'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 165 (delta 73), reused 133 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (165/165), 445.19 KiB | 3.48 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# c9f65b9 (HEAD -> main, origin/main, origin/HEAD) docs: add one-page PDF report for Apr 20

# %% [markdown]
# ## 3. HuggingFace auth
#
# Paste your token, run the cell, then **clear the token from the cell before sharing this notebook.**

# %%
from huggingface_hub import login
HF_TOKEN = "hf_REDACTED_ROTATE_PLEASE"
login(token=HF_TOKEN)

# %% [markdown]
# ## 4. Mount Drive + install extras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -e /content/AgentMorph[models,smolagents,langgraph,agentdojo]
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.4/192.4 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.1/515.1 kB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 77.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.9/635.9 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.5/350.5 kB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 91.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 23.4 MB/s eta 0:00:00
#   Building editable for agentmorph (pyproject.toml) ... done

# %% [markdown]
# ## 5. Set the model for this notebook
#
# Each notebook is named after the model it runs.

# %%
MODEL = "Llama-3.1-8B"
print("this notebook will run:", MODEL)
# Out:
# this notebook will run: Llama-3.1-8B

# %% [markdown]
# ## 6. (Optional) wipe prior `Llama-3.1-8B` cells from the shared run
#
# Prunes ONLY this model's rows from the shared `manifest.json` + deletes its JSONL files, leaving other models' progress untouched. Run after an adapter fix when you want to retry this model's trajectories from scratch.

# %%
import json, pathlib
RUN_DIR = pathlib.Path("/content/drive/MyDrive/AgentMorph/runs/stage1_baseline")
manifest_path = RUN_DIR / "manifest.json"
traj_dir = RUN_DIR / "trajectories"

if manifest_path.exists():
    data = json.loads(manifest_path.read_text())
    before = len(data.get("completed", {}))
    data["completed"] = {k: v for k, v in data.get("completed", {}).items() if not k.startswith(MODEL + "|")}
    after = len(data["completed"])
    manifest_path.write_text(json.dumps(data, indent=2))
    print(f"manifest: {before} -> {after} entries (dropped {before - after} for {MODEL})")
else:
    print("no manifest - nothing to prune")

if traj_dir.exists():
    for p in traj_dir.glob(f"{MODEL}__*.jsonl"):
        p.unlink()
        print("deleted:", p.name)
else:
    print("no trajectory dir yet")
# Out:
# manifest: 160 -> 160 entries (dropped 0 for Llama-3.1-8B)

# %% [markdown]
# ## 7. Smoke test - `Llama-3.1-8B` x native x 3 scenarios
#
# Proves the model loads and tools + trajectory logger work end-to-end. Writes to `stage1_smoke_<MODEL>/` (separate from the baseline dir) so it doesn't pollute §8.

# %%
# !python -m agentmorph.runner \
    --model {MODEL} --framework native --env ecommerce --n-scenarios 3 \
    --hf-cache-dir /content/drive/MyDrive/AgentMorph/hf_cache \
    --out-dir /content/drive/MyDrive/AgentMorph/runs/stage1_smoke_{MODEL}
# Out:
# tokenizer_config.json: 55.4kB [00:00, 14.7MB/s]
# tokenizer.json: 9.09MB [00:01, 8.01MB/s]
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 2.37MB/s]
# config.json: 100% 855/855 [00:00<00:00, 6.78MB/s]
# 2026-04-21 03:54:59.588352: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776743699.610494    1198 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776743699.616871    1198 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776743699.633463    1198 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776743699.633504    1198 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776743699.633509    1198 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776743699.633513    1198 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-21 03:54:59.638026: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors.index.json: 23.9kB [00:00, 65.7MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:02<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   1% 67.1M/4.98G [00:02<00:14, 331MB/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
# model-00003-of-00004.safetensors:   1% 67.0M/4.92G [00:03<00:14, 333MB/s]
#
#
# model-00002-of-00004.safetensors:   1% 67.1M/5.00G [00:03<00:13, 358MB/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:04<?, ?B/s]
#
#
#
# model-00001-of-00004.safetensors:   3% 134M/4.98G [00:04<01:13, 65.6MB/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:04<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:04<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:04<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:04<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:05<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:05<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:05<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:05<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:05<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:06<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:06<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:06<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:06<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:06<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:07<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:07<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:07<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:07<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:07<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:08<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:08<?, ?B/s]
#
# model-00004-of-00004.safetensors:  23% 268M/1.17G [00:08<00:00, 1.28GB/s]
#
# model-00004-of-00004.safetensors:  29% 335M/1.17G [00:09<00:03, 264MB/s]
# model-00003-of-00004.safetensors:   4% 201M/4.92G [00:09<02:55, 26.8MB/s]
# model-00003-of-00004.safetensors:   5% 268M/4.92G [00:11<02:36, 29.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:   4% 201M/4.98G [00:11<04:42, 16.9MB/s]
#
#
# model-00002-of-00004.safetensors:   4% 201M/5.00G [00:12<04:12, 19.0MB/s]
#
#
# model-00002-of-00004.safetensors:   5% 268M/5.00G [00:13<03:12, 24.6MB/s]
#
# model-00004-of-00004.safetensors:  29% 335M/1.17G [00:21<00:03, 264MB/s]
#
# model-00004-of-00004.safetensors:  34% 402M/1.17G [00:25<00:53, 14.4MB/s]
#
#
# model-00002-of-00004.safetensors:   5% 268M/5.00G [00:31<03:12, 24.6MB/s]
#
#
#
# model-00001-of-00004.safetensors:   4% 201M/4.98G [00:31<04:42, 16.9MB/s]
# model-00003-of-00004.safetensors:   5% 268M/4.92G [00:31<02:36, 29.7MB/s]
#
#
# model-00002-of-00004.safetensors:   9% 469M/5.00G [00:32<05:29, 13.7MB/s]
#
#
#
# model-00001-of-00004.safetensors:   7% 335M/4.98G [00:32<08:53, 8.70MB/s]
#
#
#
# model-00001-of-00004.safetensors:  19% 939M/4.98G [00:33<01:42, 39.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  22% 1.12G/4.98G [00:33<01:13, 52.3MB/s]
#
# model-00004-of-00004.safetensors: 100% 1.17G/1.17G [00:33<00:00, 34.7MB/s]
#
# model-00003-of-00004.safetensors:   7% 335M/4.92G [00:33<10:07, 7.54MB/s]
# model-00003-of-00004.safetensors:  18% 872M/4.92G [00:38<02:18, 29.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  36% 1.81G/4.98G [00:43<00:52, 60.1MB/s]
#
#
# model-00002-of-00004.safetensors:  27% 1.34G/5.00G [00:44<01:35, 38.5MB/s]
#
#
#
# model-00001-of-00004.safetensors:  42% 2.08G/4.98G [00:50<00:55, 52.3MB/s]
# model-00003-of-00004.safetensors:  18% 872M/4.92G [00:51<02:18, 29.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  43% 2.15G/4.98G [00:52<00:55, 51.3MB/s]
#
#
# model-00002-of-00004.safetensors:  39% 1.94G/5.00G [00:54<01:07, 45.4MB/s]
# model-00003-of-00004.safetensors:  40% 1.94G/4.92G [00:54<01:02, 47.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  53% 2.62G/4.98G [01:02<00:48, 48.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  54% 2.68G/4.98G [01:08<00:59, 38.3MB/s]
#
#
# model-00002-of-00004.safetensors:  39% 1.94G/5.00G [01:11<01:07, 45.4MB/s]
# model-00003-of-00004.safetensors:  40% 1.94G/4.92G [01:11<01:02, 47.3MB/s]
#
#
# model-00002-of-00004.safetensors:  52% 2.62G/5.00G [01:19<01:06, 35.7MB/s]
# model-00003-of-00004.safetensors:  53% 2.62G/4.92G [01:19<01:02, 37.1MB/s]
#
#
#
# model-00001-of-00004.safetensors:  54% 2.68G/4.98G [01:21<00:59, 38.3MB/s]
#
#
#
# model-00001-of-00004.safetensors:  67% 3.35G/4.98G [01:28<00:46, 35.1MB/s]
#
#
# model-00002-of-00004.safetensors:  52% 2.62G/5.00G [01:31<01:06, 35.7MB/s]
# model-00003-of-00004.safetensors:  53% 2.62G/4.92G [01:31<01:02, 37.1MB/s]
# model-00003-of-00004.safetensors:  68% 3.35G/4.92G [01:38<00:42, 37.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  74% 3.69G/4.98G [01:38<00:37, 34.7MB/s]
#
#
# model-00002-of-00004.safetensors:  67% 3.35G/5.00G [01:39<00:45, 36.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80% 3.96G/4.98G [01:49<00:32, 31.5MB/s]
#
#
# model-00002-of-00004.safetensors:  67% 3.35G/5.00G [01:51<00:45, 36.2MB/s]
# model-00003-of-00004.safetensors:  68% 3.35G/4.92G [01:51<00:42, 37.2MB/s]
#
#
#
# model-00001-of-00004.safetensors:  80% 3.96G/4.98G [02:01<00:32, 31.5MB/s]
#
#
# model-00002-of-00004.safetensors:  80% 4.02G/5.00G [02:05<00:30, 31.5MB/s]
# model-00003-of-00004.safetensors:  83% 4.09G/4.92G [02:06<00:25, 32.8MB/s]
#
#
#
# model-00001-of-00004.safetensors:  92% 4.56G/4.98G [02:10<00:13, 30.6MB/s]
#
#
#
# model-00001-of-00004.safetensors: 100% 4.98G/4.98G [02:18<00:00, 35.9MB/s]
#
#
#
# model-00002-of-00004.safetensors:  80% 4.02G/5.00G [02:21<00:30, 31.5MB/s]
# model-00003-of-00004.safetensors:  83% 4.09G/4.92G [02:21<00:25, 32.8MB/s]
#
#
# Fetching 4 files:  25% 1/4 [02:30<07:31, 150.55s/it]
# model-00003-of-00004.safetensors:  98% 4.83G/4.92G [02:33<00:02, 30.5MB/s]
# model-00003-of-00004.safetensors: 100% 4.92G/4.92G [02:34<00:00, 31.8MB/s]
#
#
#
# model-00002-of-00004.safetensors: 100% 5.00G/5.00G [02:35<00:00, 32.1MB/s]
# Fetching 4 files: 100% 4/4 [02:36<00:00, 39.21s/it]
# Loading checkpoint shards: 100% 4/4 [01:53<00:00, 28.43s/it]
# generation_config.json: 100% 184/184 [00:00<00:00, 154kB/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# {
#   "total_cells": 3,
#   "ran": 3,
#   "skipped": 0,
#   "errored": 0,
#   "out_dir": "/content/drive/MyDrive/AgentMorph/runs/stage1_smoke_Llama-3.1-8B"
# }

# %% [markdown]
# ## 8. Framework sweep - `Llama-3.1-8B` x (native + langgraph) x ecommerce x 20 scenarios
#
# Resumable. Writes into the shared `stage1_baseline/` directory.
#
# **Why `native + langgraph` only (not smolagents):** smolagents injects all 30 tool descriptions into every turn's prompt, which on small open models snowballs input context to 20K+ tokens by step 3 and triggers CUDA OOM on a 14.6 GB T4. The smolagents adapter stays in the code — add `--framework smolagents` below to test it on larger / more tool-calling-capable models (Qwen2.5-7B, Gemma-2-9B, Phi-4).

# %%
import os
# Reduce CUDA allocator fragmentation on long multi-scenario runs.
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True python -m agentmorph.runner \
    --model {MODEL} --framework native --framework langgraph --env ecommerce \
    --hf-cache-dir /content/drive/MyDrive/AgentMorph/hf_cache \
    --out-dir /content/drive/MyDrive/AgentMorph/runs/stage1_baseline
# Out:
# 2026-04-21 04:01:18.596617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776744078.619769    2839 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776744078.625600    2839 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776744078.641252    2839 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776744078.641292    2839 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776744078.641297    2839 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776744078.641303    2839 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-21 04:01:18.645113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:17<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:18<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:19<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:20<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:21<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:22<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:23<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:24<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:25<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:26<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:27<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:28<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:29<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:30<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:31<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:32<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:33<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:34<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:35<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:36<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:37<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:38<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:39<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:40<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:41<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:42<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:43<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:44<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:45<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:46<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:47<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:48<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:49<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:50<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:51<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:52<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:53<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:54<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:55<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:56<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:57<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:58<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [01:59<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:01<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:02<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:03<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:04<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:05<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:06<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:07<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:08<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:09<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:10<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:11<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:12<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:13<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:14<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:15<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:16<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [02:16<?, ?B/s]
# model-00001-of-00004.safetensors:   1% 67.1M/4.98G [02:16<00:14, 335MB/s]
# model-00001-of-00004.safetensors:   3% 134M/4.98G [02:17<00:31, 154MB/s]
# model-00001-of-00004.safetensors:   4% 201M/4.98G [02:17<00:23, 203MB/s]
# model-00001-of-00004.safetensors:   5% 268M/4.98G [02:18<00:30, 154MB/s]
# model-00001-of-00004.safetensors:   8% 403M/4.98G [02:18<00:24, 185MB/s]
# model-00001-of-00004.safetensors:   9% 470M/4.98G [02:19<00:25, 180MB/s]
# model-00001-of-00004.safetensors:  12% 604M/4.98G [02:22<01:03, 69.1MB/s]
# model-00001-of-00004.safetensors:  24% 1.21G/4.98G [02:28<00:40, 92.8MB/s]
# model-00001-of-00004.safetensors:  40% 2.01G/4.98G [02:34<00:26, 111MB/s]
# model-00001-of-00004.safetensors:  73% 3.62G/4.98G [02:46<00:11, 122MB/s]
# model-00001-of-00004.safetensors:  90% 4.49G/4.98G [02:50<00:03, 143MB/s]
# model-00001-of-00004.safetensors: 100% 4.98G/4.98G [02:52<00:00, 28.8MB/s]
# Fetching 4 files: 100% 4/4 [02:54<00:00, 43.55s/it]
# Loading checkpoint shards: 100% 4/4 [02:28<00:00, 37.23s/it]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# {
#   "total_cells": 40,
#   "ran": 40,
#   "skipped": 0,
#   "errored": 0,
#   "out_dir": "/content/drive/MyDrive/AgentMorph/runs/stage1_baseline"
# }

# %% [markdown]
# ## 9. Diagnostic - full error text for Llama-3.1-8B
#
# Prints the complete (non-truncated) content of the first error step per framework. Paste back here if anything fails.

# %%
import json, pathlib
traj_dir = pathlib.Path("/content/drive/MyDrive/AgentMorph/runs/stage1_baseline/trajectories")
for p in sorted(traj_dir.glob(f"{MODEL}__*.jsonl")):
    print(f"\n======= {p.name} =======")
    shown = False
    for line in p.open():
        t = json.loads(line)
        errs = [s for s in t["steps"] if s["kind"] == "error"]
        if errs and not shown:
            print(f"scenario: {t['scenario_id']}")
            print(f"steps: {len(t['steps'])}  final_answer: {t['final_answer']!r}")
            print("FULL ERROR TEXT:")
            print(errs[0]["content"])
            shown = True
            break
    if not shown:
        print("(no error steps in this file - all trajectories finished cleanly!)")
# Out:
# ======= Llama-3.1-8B__langgraph__ecommerce.jsonl =======
# scenario: eco_checkout_promo
# steps: 1  final_answer: None
# FULL ERROR TEXT:
# langgraph adapter failed: KeyError: 'no product 123'
#
# ======= Llama-3.1-8B__native__ecommerce.jsonl =======
# scenario: eco_shop_kettle
# steps: 10  final_answer: None
# FULL ERROR TEXT:
# max_steps exhausted without a FINAL answer

# %% [markdown]
# ## 10. Finish-rate for `Llama-3.1-8B`

# %%
import json, collections, pathlib
traj_dir = pathlib.Path("/content/drive/MyDrive/AgentMorph/runs/stage1_baseline/trajectories")
stats = collections.defaultdict(lambda: [0, 0])
for p in traj_dir.glob(f"{MODEL}__*.jsonl"):
    for line in p.open():
        t = json.loads(line)
        key = (t["model_id"], t["framework_id"])
        stats[key][0] += 1
        if t["final_answer"]:
            stats[key][1] += 1
print(f"=== {MODEL} finish rate ===")
for (m, f), (tot, fin) in sorted(stats.items()):
    pct = 100 * fin / tot if tot else 0
    print(f"  {f:10s}  finished {fin:2d}/{tot:2d}  ({pct:3.0f}%)")
# Out:
# === Llama-3.1-8B finish rate ===
#   langgraph   finished 12/20  ( 60%)
#   native      finished  0/20  (  0%)

# %% [markdown]
# ## 11. Peek one trajectory from `Llama-3.1-8B`

# %%
import json, pathlib
traj_dir = pathlib.Path("/content/drive/MyDrive/AgentMorph/runs/stage1_baseline/trajectories")
for p in sorted(traj_dir.glob(f"{MODEL}__*.jsonl")):
    sample = p.open().readline()
    if not sample:
        continue
    t = json.loads(sample)
    print(f"\n======= {p.name} =======")
    print(f"scenario: {t['scenario_id']}")
    print(f"framework: {t['framework_id']}")
    print(f"steps: {len(t['steps'])}  wall_seconds: {t.get('wall_seconds') or 0:.1f}")
    print(f"final_answer: {t['final_answer']!r}\n")
    for s in t["steps"][:20]:
        tag = s["kind"]
        if tag == "tool_call":
            print(f"  [{tag}] {s['tool_name']}({s['tool_args']})")
        elif tag == "tool_result":
            print(f"  [{tag}] {s['tool_name']} -> {str(s['tool_output'])[:80]}")
        else:
            print(f"  [{tag}] {str(s.get('content', ''))[:200]}")
# Out:
# ======= Llama-3.1-8B__langgraph__ecommerce.jsonl =======
# scenario: eco_shop_kettle
# framework: langgraph
# steps: 6  wall_seconds: 21.0
# final_answer: "Now, let's check the cart total."
#
#   [tool_call] search_products({'query': 'kettle', 'min_price': 0, 'max_price': 50, 'limit': 1})
#   [tool_result] search_products -> [{"id": "P020", "name": "Electric Kettle", "category": "kitchen", "price": 39.0,
#   [tool_call] add_to_cart({'product_id': 'P020', 'quantity': 1})
#   [tool_result] add_to_cart -> {"items": [{"product_id": "P020", "name": "Electric Kettle", "unit_price": 39.0,
#   [thought] Now, let's check the cart total.
#   [final_answer] Now, let's check the cart total.
#
# ======= Llama-3.1-8B__native__ecommerce.jsonl =======
# scenario: eco_shop_kettle
# framework: native
# steps: 10  wall_seconds: 9.7
# final_answer: None
#
#   [thought] ```json
# {"tool": "search_products", "arguments": {"query": "kettle", "max_price": 50}}
# ```
#   [tool_call] search_products({'query': 'kettle', 'max_price': 50})
#   [tool_result] search_products -> [{'id': 'P020', 'name': 'Electric Kettle', 'category': 'kitchen', 'price': 39.0,
#   [thought] ```json
# {"tool": "add_to_cart", "arguments": {"product_id": "P020", "quantity": 1}}
# ```
#   [tool_call] add_to_cart({'product_id': 'P020', 'quantity': 1})
#   [tool_result] add_to_cart -> {'items': [{'product_id': 'P020', 'name': 'Electric Kettle', 'unit_price': 39.0,
#   [thought] ```json
# {"tool": "view_cart"}
# ```
#   [tool_call] view_cart({})
#   [tool_result] view_cart -> {'items': [{'product_id': 'P020', 'name': 'Electric Kettle', 'unit_price': 39.0,
#   [error] max_steps exhausted without a FINAL answer
